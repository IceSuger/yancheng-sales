# %%
import pandas as pd
import numpy as np
from pandas.tseries.offsets import *
from xiao_utils import f

# %%
# 注意要把表中的 0 也都按空值 nan 处理，因为实际上不可能有真正有意义的 0 出现的！
df_CB = pd.read_csv("../../data/features/CB_features.csv", dtype={'sale_date':str}, na_values=['-',0], low_memory=False)
df_CB['sale_date']= pd.to_datetime(df_CB['sale_date'])
# df_C = df_C.drop('C_rcm_0', axis=1)

# %%
df_OC = pd.read_csv("../../data/features/OC_features_online.csv", dtype={'sale_date':str}, na_values=['-',0], low_memory=False)

# %%
df_CB
# Out:
#       class_id  sale_date  sale_quantity  C_som_1  C_som_2  C_som_3  C_som_4  \
# 0       103507 2015-03-01           58.0      NaN      NaN      NaN      NaN
# 1       103507 2015-04-01          232.0     58.0      NaN      NaN      NaN
# 2       103507 2015-05-01          226.0    232.0     58.0      NaN      NaN
# 3       103507 2015-06-01          286.0    226.0    232.0     58.0      NaN
# 4       103507 2015-07-01          297.0    286.0    226.0    232.0     58.0
# 5       103507 2015-08-01          355.0    297.0    286.0    226.0    232.0
# 6       103507 2015-09-01          442.0    355.0    297.0    286.0    226.0
# 7       103507 2015-10-01         1050.0    442.0    355.0    297.0    286.0
# 8       103507 2015-11-01          481.0   1050.0    442.0    355.0    297.0
# 9       103507 2015-12-01         1433.0    481.0   1050.0    442.0    355.0
# 10      103507 2016-01-01          993.0   1433.0    481.0   1050.0    442.0
# ...

# %%
df_OC
# Out:
#      class_id  OC_mode_compartment  OC_mode_displacement  OC_mode_price_level  \
# 0      103507                    2                   1.6                  3.0
# 1      124140                    2                   1.8                  3.0
# 2      125403                    2                   2.4                  7.0
# 3      136916                    3                   2.0                  4.0
# 4      169673                    2                   1.5                  1.0
# 5      175962                    3                   1.6                  3.0
# 6      178529                    1                   1.0                  NaN
# 7      186250                    2                   1.5                  3.0
# 8      194201                    2                   1.4                  2.0
# 9      194450                    2                   1.6                  4.0
# 10     198427                    3                   1.5                  1.0
# ...

# %%
features = pd.merge(df_CB, df_OC, how='left', on='class_id')

# %%
features
# Out:
#       class_id  sale_date  sale_quantity  C_som_1  C_som_2  C_som_3  C_som_4  \
# 0       103507 2015-03-01           58.0      NaN      NaN      NaN      NaN
# 1       103507 2015-04-01          232.0     58.0      NaN      NaN      NaN
# 2       103507 2015-05-01          226.0    232.0     58.0      NaN      NaN
# 3       103507 2015-06-01          286.0    226.0    232.0     58.0      NaN
# 4       103507 2015-07-01          297.0    286.0    226.0    232.0     58.0
# 5       103507 2015-08-01          355.0    297.0    286.0    226.0    232.0
# 6       103507 2015-09-01          442.0    355.0    297.0    286.0    226.0
# 7       103507 2015-10-01         1050.0    442.0    355.0    297.0    286.0
# 8       103507 2015-11-01          481.0   1050.0    442.0    355.0    297.0
# 9       103507 2015-12-01         1433.0    481.0   1050.0    442.0    355.0
# 10      103507 2016-01-01          993.0   1433.0    481.0   1050.0    442.0
# ...

# %%
features.to_csv("../../data/features/final_features_CB+OC.csv",index=False)
